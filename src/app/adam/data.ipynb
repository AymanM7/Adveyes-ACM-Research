# %%
import pandas as pd

# %%
df = pd.read_csv("CPT_Summary.csv")
df
# Out:
#                 Unnamed: 0     ADHD_Mean       ADHD_SD   NoADHD_Mean  \
# 0              block_index  2.000000e+00  8.199201e-01  2.000000e+00
# 1       trial_index_global  1.100000e+01  8.199201e+00  1.100000e+01
# 2        trial_index_block  5.500000e+00  2.884324e+00  5.500000e+00
# 3                is_target  2.000000e-01  4.016772e-01  2.000000e-01
# 4           has_distractor  9.333333e-01  2.504897e-01  8.916667e-01
# 5      distractor_onset_ms  2.785385e+02  7.113362e+01  2.830400e+02
# 6   distractor_duration_ms  1.908910e+03  4.862281e+02  1.954573e+03
# 7      distractor_pos_px_x  6.943462e+02  5.677645e+02  6.891467e+02
# 8      distractor_pos_px_y  3.098974e+02  2.057730e+02  3.052533e+02
# 9         stim_duration_ms  1.380000e+03  8.981774e+01  1.370000e+03
# 10                  isi_ms  8.000000e+02  0.000000e+00  8.000000e+02
# 11        response_time_ms  8.711875e+02  2.467647e+02  6.556500e+02
# 12                  is_hit  1.166667e-01  3.223687e-01  1.500000e-01
# ...
